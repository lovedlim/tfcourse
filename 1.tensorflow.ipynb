# %% [markdown]
# ## 텐서플로 가이드
# - 한글: https://www.tensorflow.org/guide?hl=ko
# - 원문: https://www.tensorflow.org/guide
#
# ## 텐서플로 튜토리얼
# - 한글: https://www.tensorflow.org/tutorials?hl=ko
# - 원문: https://www.tensorflow.org/tutorials
#
# ## 텐서플로 API
# - https://www.tensorflow.org/api_docs/python/tf

# %%
# 텐서플로 라이브러리 불러오기
import tensorflow as tf

# %%
# 텐서플로 버전
tf.__version__
# Out:
# '2.5.0'

# %% [markdown]
# ## 이미지 분류 모델(예시)

# %%
# 이미지 분류 
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(256, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(x_train, y_train, batch_size=64, epochs=5)
# Out:
# Epoch 1/5
# 938/938 [==============================] - 4s 3ms/step - loss: 3.4172 - accuracy: 0.8300
# Epoch 2/5
# 938/938 [==============================] - 3s 3ms/step - loss: 0.4723 - accuracy: 0.8879
# Epoch 3/5
# 938/938 [==============================] - 3s 4ms/step - loss: 0.3620 - accuracy: 0.9108
# Epoch 4/5
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3101 - accuracy: 0.9196
# Epoch 5/5
# 938/938 [==============================] - 3s 3ms/step - loss: 0.2819 - accuracy: 0.9273

# %%
import matplotlib.pyplot as plt

def plot_graphs(history, metric):
  plt.plot(history.history[metric])
  plt.xlabel("Epochs")
  plt.ylabel(metric)
  plt.show()

plot_graphs(history, 'accuracy')
