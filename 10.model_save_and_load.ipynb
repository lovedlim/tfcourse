# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# %% [markdown]
# ## 모델 가중치 저장 및 불러오기

# %%
cp_path = 'model_save/cp.ckpt'
checkpoint = ModelCheckpoint(filepath=cp_path,
                            save_best_only=True,
                            save_weights_only=True,
                            verbose=1)

# %%
# 라이브러리 불러오기
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten

# Mnist 데이터셋
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# 열악한 학습데이터 환경 설정 (5000개)
x_train = x_train[:5000]
y_train = y_train[:5000]

# 모델 (함수)
def load_model():
    model = Sequential([
                        Flatten(input_shape=(28,28)),
                        Dense(64, activation='relu'),
                        Dense(10, activation='softmax')
    ])

    model.compile(optimizer='adam',
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])
    return model
    
model = load_model()
model.fit(x_train, y_train, validation_split=0.2, epochs=10, batch_size=64, callbacks=[checkpoint], verbose=2)
# Out:
# Epoch 1/10
# 63/63 - 1s - loss: 18.6711 - accuracy: 0.6230 - val_loss: 6.4626 - val_accuracy: 0.7540
#
# Epoch 00001: val_loss improved from inf to 6.46260, saving model to model_save/cp.ckpt
# Epoch 2/10
# 63/63 - 0s - loss: 3.0998 - accuracy: 0.8055 - val_loss: 3.9075 - val_accuracy: 0.7770
#
# Epoch 00002: val_loss improved from 6.46260 to 3.90755, saving model to model_save/cp.ckpt
# Epoch 3/10
# 63/63 - 0s - loss: 1.5099 - accuracy: 0.8405 - val_loss: 2.9453 - val_accuracy: 0.7810
#
# Epoch 00003: val_loss improved from 3.90755 to 2.94532, saving model to model_save/cp.ckpt
# Epoch 4/10
# 63/63 - 0s - loss: 0.8752 - accuracy: 0.8798 - val_loss: 3.0244 - val_accuracy: 0.8010
#
# Epoch 00004: val_loss did not improve from 2.94532
# Epoch 5/10
# 63/63 - 0s - loss: 0.5841 - accuracy: 0.9050 - val_loss: 2.2153 - val_accuracy: 0.8170
#
# Epoch 00005: val_loss improved from 2.94532 to 2.21533, saving model to model_save/cp.ckpt
# Epoch 6/10
# 63/63 - 0s - loss: 0.4282 - accuracy: 0.9155 - val_loss: 2.5240 - val_accuracy: 0.8180
#
# Epoch 00006: val_loss did not improve from 2.21533
# Epoch 7/10
# 63/63 - 0s - loss: 0.2884 - accuracy: 0.9420 - val_loss: 2.3130 - val_accuracy: 0.8230
#
# Epoch 00007: val_loss did not improve from 2.21533
# Epoch 8/10
# 63/63 - 0s - loss: 0.2214 - accuracy: 0.9448 - val_loss: 2.3103 - val_accuracy: 0.8260
#
# Epoch 00008: val_loss did not improve from 2.21533
# Epoch 9/10
# 63/63 - 0s - loss: 0.1876 - accuracy: 0.9538 - val_loss: 2.5350 - val_accuracy: 0.8290
#
# Epoch 00009: val_loss did not improve from 2.21533
# Epoch 10/10
# 63/63 - 0s - loss: 0.1530 - accuracy: 0.9572 - val_loss: 2.4074 - val_accuracy: 0.8320
#
# Epoch 00010: val_loss did not improve from 2.21533

# %%
# 새 모델
model = load_model()
model.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 1ms/step - loss: 205.0957 - accuracy: 0.0559
# [205.0956573486328, 0.05590000003576279]

# %%
# 저장된 모델 가중치 불러오기
model.load_weights(cp_path)
model.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 2.1525 - accuracy: 0.7945
# [2.152540922164917, 0.7944999933242798]

# %% [markdown]
# ## 모델 전체 저장 및 불러오기

# %%
# 방법 1
model = load_model()
checkpoint = ModelCheckpoint('model_save.h5') #save_weights_only=False
model.fit(x_train, y_train, epochs=3, callbacks=[checkpoint])
# Out:
# Epoch 1/3
# 1875/1875 [==============================] - 3s 2ms/step - loss: 2.1957 - accuracy: 0.7965
# Epoch 2/3
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4497 - accuracy: 0.8873
# Epoch 3/3
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3344 - accuracy: 0.9145

# %%
# 방법 2
model = load_model()
model.fit(x_train, y_train, epochs=3)
model.save('model_save2.h5')
# Out:
# Epoch 1/3
# 1875/1875 [==============================] - 3s 2ms/step - loss: 2.4144 - accuracy: 0.7901
# Epoch 2/3
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.5033 - accuracy: 0.8712
# Epoch 3/3
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3605 - accuracy: 0.9062

# %%
from tensorflow.keras.models import load_model

model = load_model('model_save2.h5')
model.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.3356 - accuracy: 0.9157
# [0.3356322646141052, 0.9157000184059143]
