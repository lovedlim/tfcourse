# %%
# 라이브러리 불러오기
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten

# %%
# 모델 만들기
model = Sequential([
                    Flatten(input_shape=(28,28)),
                    Dense(64, activation='relu'),
                    Dense(10, activation='softmax')
])

# %%
# 모델 컴파일 방법1
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# 모델 컴파일 방법2
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=tf.keras.metrics.Accuracy())

# %%
# 문제에 따른 컴파일 예시

# 다중분류
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# 이진분류
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# 회귀
model.compile(optimizer='adam',
              loss='mse')

# %% [markdown]
# ### optimizer
# - 링크: https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Optimizer
# - 예: sgd, rmsprop, adadelta, adamax
#
# ### loss
# - 링크: https://www.tensorflow.org/api_docs/python/tf/keras/losses
# - 예: binary_crossentropy, mean_squared_error
