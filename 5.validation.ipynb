# %% [markdown]
# ## 1. validation_split 적용

# %%
# 라이브러리 불러오기
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten

# Mnist 데이터셋
mnist = tf.keras.datasets.mnist
(X, y), (x_test, y_test) = mnist.load_data()

# 시퀀셜 모델 만들기
model = Sequential([
                    Flatten(input_shape=(28,28)),
                    Dense(64, activation='relu'),
                    Dense(10, activation='softmax')
])

# 모델 컴파일
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# validation_split 활용
history = model.fit(X, y, validation_split=0.2, epochs=5, batch_size=64)
# Out:
# Epoch 1/5
# 750/750 [==============================] - 2s 2ms/step - loss: 3.4466 - accuracy: 0.7449 - val_loss: 0.7522 - val_accuracy: 0.8234
# Epoch 2/5
# 750/750 [==============================] - 1s 2ms/step - loss: 0.6259 - accuracy: 0.8560 - val_loss: 0.5570 - val_accuracy: 0.8816
# Epoch 3/5
# 750/750 [==============================] - 1s 2ms/step - loss: 0.4569 - accuracy: 0.8916 - val_loss: 0.4625 - val_accuracy: 0.9092
# Epoch 4/5
# 750/750 [==============================] - 1s 2ms/step - loss: 0.3629 - accuracy: 0.9118 - val_loss: 0.3819 - val_accuracy: 0.9154
# Epoch 5/5
# 750/750 [==============================] - 1s 2ms/step - loss: 0.3047 - accuracy: 0.9238 - val_loss: 0.3669 - val_accuracy: 0.9232

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(['training', 'validation'])

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['training', 'validation'])

# %% [markdown]
# ## 2. train_test_split 활용

# %%
# train_test_split 활용
from sklearn.model_selection import train_test_split
x_train, x_val, y_train, y_val = train_test_split(X, y, test_size=0.2)

x_train.shape, x_val.shape
# Out:
# ((48000, 28, 28), (12000, 28, 28))

# %%
# 시퀀셜 모델 만들기
model = Sequential([
                    Flatten(input_shape=(28,28)),
                    Dense(64, activation='relu'),
                    Dense(10, activation='softmax')
])

# 모델 컴파일
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# 훈련(학습) validation_data
history = model.fit(x_train, y_train, validation_data=(x_val, y_val), epochs=5, batch_size=64)
# Out:
# Epoch 1/5
# 750/750 [==============================] - 2s 2ms/step - loss: 3.3690 - accuracy: 0.7344 - val_loss: 0.7719 - val_accuracy: 0.8019
# Epoch 2/5
# 750/750 [==============================] - 1s 2ms/step - loss: 0.5746 - accuracy: 0.8485 - val_loss: 0.4912 - val_accuracy: 0.8729
# Epoch 3/5
# 750/750 [==============================] - 1s 2ms/step - loss: 0.3877 - accuracy: 0.8972 - val_loss: 0.4085 - val_accuracy: 0.8980
# Epoch 4/5
# 750/750 [==============================] - 1s 2ms/step - loss: 0.3097 - accuracy: 0.9178 - val_loss: 0.3505 - val_accuracy: 0.9143
# Epoch 5/5
# 750/750 [==============================] - 1s 2ms/step - loss: 0.2668 - accuracy: 0.9287 - val_loss: 0.3473 - val_accuracy: 0.9134

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(['training', 'validation'])

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['training', 'validation'])
